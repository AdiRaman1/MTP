# %%
# !pip install pillow
from PIL import Image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
# %matplotlib inline
pic1 = imageio.imread('/intensity_image/5_1_f411.jpg')
plt.imshow(pic1)

# %%
pic2 = imageio.imread('/intensity_image/5_2_f262.jpg')
plt.imshow(pic2)

# %%
pic3 = imageio.imread('/intensity_image/5_3_f571.jpg')
plt.imshow(pic3)

# %%
pic4 = imageio.imread('/intensity_image/10_1_f286.jpg')
plt.imshow(pic3)
plt.savefig("10.png")
files.download("10.png")

# %%
pic5 = imageio.imread('/intensity_image/10_2_f523.jpg')
plt.imshow(pic5)

# %%
pic6 = imageio.imread('/intensity_image/10_3_f724.jpg')
plt.imshow(pic6)

# %%
pic7 = imageio.imread('/intensity_image/15_1_f532.jpg')
plt.imshow(pic7)

# %%
pic8 = imageio.imread('/intensity_image/15_2_f307.jpg')
plt.imshow(pic8)

# %%
pic9 = imageio.imread('/intensity_image/15_3_f995.jpg')
plt.imshow(pic9)

# %%
pic10 = imageio.imread('/intensity_image/20_1_f691.jpg')
plt.imshow(pic10)

# %%
print('Type of the image : ' , type(pic1))
print()
print('Shape of the image : {}'.format(pic1.shape))
print('Image Hight {}'.format(pic1.shape[0]))
print('Image Width {}'.format(pic1.shape[1]))
print('Dimension of Image {}'.format(pic1.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (320, 240, 3)
# Image Hight 320
# Image Width 240
# Dimension of Image 3

# %%
total_row , total_col , layers = pic1.shape

# %%
im = Image.open('/content/5_3_f571.jpg', 'r')
pix_val = list(im.getdata())

# %%
pix_val_flat = [x for sets in pix_val for x in sets]

# %%
a=[]
for i in range(len(pix_val_flat)):
  if pix_val_flat[i]>254:
    a.append(pix_val_flat[i])

# %%
len(pix_val)
# Out:
# 76800

# %%
print('Image size {}'.format(pic1.size))
print('Maximum RGB value in this image {}'.format(pic1.max()))
print('Minimum RGB value in this image {}'.format(pic1.min()))
# Out:
# Image size 230400
# Maximum RGB value in this image 253
# Minimum RGB value in this image 0

# %%
a1 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic1[i,j,0]
  a1.append(s/70)

# %%
a2 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic2[i,j,0]
  a2.append(s/70)

# %%
a3 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic3[i,j,0]
  a3.append(s/70)

# %%
a4 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic4[i,j,0]
  a4.append(s/70)

# %%
a5 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic5[i,j,0]
  a5.append(s/70)

# %%
a6 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic6[i,j,0]
  a6.append(s/70)

# %%
a7 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic7[i,j,0]
  a7.append(s/70)

# %%
a8 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic8[i,j,0]
  a8.append(s/70)

# %%
a9 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic9[i,j,0]
  a9.append(s/70)

# %%
a10 = []
for i in range(0,110):
  s = 0
  for j in range(90,160):
    s = s+pic10[i,j,0]
  a10.append(s/70)

# %%
a78=[]
for i in range(0,110):
  a78.append((a7[i]+a8[i]+a9[i])/3)

# %%
q=range(0,110)

# %%
plt.figure()
plt.plot(q,a1,label='5_1', color = 'r')
plt.plot(q,a2,label='5_2', color = 'r')
plt.plot(q,a3,label='5_3', color = 'r')
plt.plot(q,a4,label='10_1', color ='b')
plt.plot(q,a5,label='10_2', color = 'b')
plt.plot(q,a6,label='10_3', color = 'b')
plt.plot(q,a7,label='15_1', color = 'g')
plt.plot(q,a8,label='15_2', color = 'g')
plt.plot(q,a9,label='15_3', color = 'g')
plt.plot(q,a10,label='20_1', color = 'y')


plt.ylabel('Intensity')
plt.xlabel('Pixel')
plt.title('Intensity Curve')
plt.legend()
plt.show()

# %%
a12=[]
for i in range(0,110):
  a12.append((a1[i]+a2[i]+a3[i])/3)

# %%
a45=[]
for i in range(0,110):
  a45.append((a4[i]+a5[i]+a6[i])/3)

# %%
plt.figure()

plt.plot(q,a12, label='5\u2070 Brix', color = 'r')
plt.plot(q,a45, label='10\u2070 Brix', color = 'b')
plt.plot(q,a78, label='15\u2070 Brix', color = 'g')
plt.plot(q,a10, label='20\u2070 Brix', color = 'y')
plt.ylabel('Intensity')
plt.xlabel('Pixel')
plt.title('Intensity Curve')
plt.legend()
plt.savefig("Intensity.png")
files.download("Intensity.png")

# %%
a123 = np.gradient(a12, axis = None, edge_order= 1)
a123
# Out:
# array([ 0.74761905,  1.01428571,  1.21666667,  1.31428571,  1.25714286,
#         1.07380952,  1.45714286,  1.7047619 ,  1.8047619 ,  1.94285714,
#         1.7       ,  1.91190476,  2.06190476,  1.7952381 ,  1.59761905,
#         2.62380952,  2.68095238,  1.84285714,  2.60238095,  3.01666667,
#         2.98095238,  2.8452381 ,  2.55714286,  2.15952381,  2.12380952,
#         2.46428571,  2.63095238,  2.63333333,  2.64285714,  2.45714286,
#         1.92857143,  3.03333333,  3.10952381,  2.15238095,  2.65714286,
#         2.99047619,  3.1       ,  3.0452381 ,  3.06428571,  3.1452381 ,
#         3.1452381 ,  3.21190476,  3.30952381,  3.32142857,  3.18571429,
#         2.71904762,  2.23333333,  3.66190476,  3.48095238,  2.29047619,
#         3.05      ,  3.46904762,  3.8       ,  3.74047619,  3.71190476,
#         3.8       ,  3.70952381,  3.65238095,  3.80714286,  4.23809524,
#         4.20952381,  3.48809524,  2.97142857,  3.88095238,  3.6       ,
# ...

# %%
import numpy as np
a = np.gradient(a78, axis = None, edge_order= 1)
b = np.gradient(a12, axis = None, edge_order= 1)
c = np.gradient(a45, axis = None, edge_order= 1)
d = np.gradient(a10, axis = None, edge_order= 1)

# %%
plt.plot(q, b, label = '5\u2070 Brix', color = 'r')
plt.plot(q, c, label = '10\u2070 Brix', color = 'b')
plt.plot(q, a, label = '15\u2070 Brix', color = 'g')
plt.plot(q, d, label = '20\u2070 Brix', color = 'y')
plt.ylabel('Gradient Intensity in A.U.')
plt.xlabel('Pixel')
plt.title('Derivative Curve')
plt.legend()
plt.savefig("Gradient.png")
files.download("Gradient.png")

# %%
max_a = max(a)
max_a_p = np.where(a==max_a)
print(max_a,max_a_p)
# Out:
# 4.1476190476190595 (array([64]),)

# %%
max_b = max(b)
max_b_p = np.where(b==max_b)
print(max_b,max_b_p)
# Out:
# 4.238095238095227 (array([59]),)

# %%
max_c = max(c)
max_c_p = np.where(c==max_c)
print(max_c,max_c_p)
# Out:
# 4.48095238095236 (array([59]),)

# %%
max_d = max(d)
max_d_p = np.where(d==max_d)
print(max_d,max_d_p)
# Out:
# 4.242857142857147 (array([63]),)

# %%
from sklearn.linear_model import LinearRegression

# %%
x = np.array([5, 10, 15]).reshape((-1, 1))
y = np.array([55, 59, 64])

# %%
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.9959016393442623
# intercept: 50.333333333333336
# slope: [0.9]

# %%
x_new=(63-model.intercept_)/model.coef_
x_new
# Out:
# array([14.07407407])
